# %% [raw]
# class and object
#
# Object--> its has properties/attribtes and functionality
# Class--> using class we can create objects is like its a blue print for object

# %%
class Employe:
    pass

# %%
emp=Employe()

# %%
type(emp)
# Out:
# __main__.Employe

# %%
print(type(emp))
# Out:
# <class '__main__.Employe'>

# %%
class Employe:
    def intro(self):
        print("my name is "+self.name)

# %%
emp1=Employe()

# %%
emp1.name="kuldeep"

# %%
emp1.intro()
# Out:
# my name is kuldeep

# %%
class Human:
    
    # this constructor
    def __init__(self, name ,gender ,age ):
        self.name=name
        self.gender=gender
        self.age=age
        
    def show(self):
        print("name is "+ self.name)
        print("gender is "+self.gender)
        print("age is "+str(self.age))

# %%
person1=Human("Kuldeep","male",24)

# %%
person1.show()
# Out:
# name is Kuldeep
# gender is male
# age is 24

# %%
person1.weigth=457

# %%
person1.weigth
# Out:
# 457

# %% [raw]
# so this mean you can create variable or attribute after intialization also

# %%
class BankAccount:

    def __init__(self,Acc_no,name,bal):
        self.Acc_no=Acc_no
        self.name=name
        self.bal=bal
        
    def deposit(self,amount):
        if amount<0:
            print("invalid amount")
        else :
            self.bal+=amount

    def display(self):
        print(f"Account number: {self.Acc_no}")
        print(f"Name : {self.name}")
        print(f"Balance : {self.bal}")

# %%
abc=BankAccount()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 abc=BankAccount()
#
# TypeError: BankAccount.__init__() missing 3 required positional arguments: 'Acc_no', 'name', and 'bal'

# %%
abc=BankAccount(123456,"kuldeep",0)

# %%
abc.Acc_no
# Out:
# 123456

# %%
abc.deposit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 abc.deposit()
#
# TypeError: BankAccount.deposit() missing 1 required positional argument: 'amount'

# %%
abc.deposit(7474)

# %%
abc.display()
# Out:
# Account number: 123456
# Name : kuldeep
# Balance : 7474
