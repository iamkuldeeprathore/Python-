# %%
#file handling

# %%
# %ls
# Out:
# Exception_handling.ipynb  Learningpython_01.ipynb   function_2.ipynb
# File_handling.ipynb       function.ipynb

# %%
pwd()
# Out:
# '/Users/vipin/Desktop/Python'

# %%
ls
# Out:
# Exception_handling.ipynb  Learningpython_01.ipynb   function_2.ipynb
# File_handling.ipynb       function.ipynb

# %%
ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ls
#
# NameError: name 'ls' is not defined

# %%
ls
# Out:
# Exception_handling.ipynb  Learningpython_01.ipynb   function_2.ipynb
# File_handling.ipynb       function.ipynb            text.txt

# %%
f=open("text.txt")

# %%
# this is when you are working in the same folder

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f.close()

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f=open(r"/Users/vipin/Desktop/Python/text.txt",'r')

# %%
# first is r is raw and second r is for read mode

# %%
f.read()
# Out:
# 'hello this is text file\nkuldeep tahto\nalkdf \n5435\n'

# %%
f.read()
# Out:
# ''

# %%
# this is because cursor is pointing at the end of previous text till it already read

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
# this seek function take a arg to what point you want your cursor/pointer

# %%
f.read
# Out:
# <function TextIOWrapper.read(size=-1, /)>

# %%
f.read(9)
# Out:
# 'hello thi'

# %%
f.tell()
# Out:
# 9

# %%
# tell give the current position of cursor you can give tell()
# function to the seek function,The return value of tell() can be given as input to seek(), to restore a
# previous stream position.

# %%
f.readline()
# Out:
# 's is text file\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'hello this is text file\n'

# %%
f.readline()
# Out:
# 'kuldeep tahto\n'

# %%
try:
    f=open("text.txt")
finally:
    f.close()

# %%
# here i am closing the file manually we can do it automaticly using with

# %%
with open("text.txt") as f:
    # do the operation
    line=f.readline()
    print(line)
    pass
# Out:
# hello this is text file

# %%
f.closed
# Out:
# True

# %%
with open("text.txt",'w') as f:
    f.write("Kuldeep rathore")

# %%
f=open("text.txt") 
f.read()
# Out:
# 'Kuldeep rathore'

# %%
# write function override the already write content
