# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.5-cp312-cp312-macosx_11_0_arm64.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.7/920.7 kB 240.4 kB/s eta 0:00:00a 0:00:01
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 126.4 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://rathorejikuldeep_db_user:<Kuldeep0412>@cluster0.riuxm9l.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
client=MongoClient(uri)

# %%
db=client.test

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-gv2ej15-shard-00-01.riuxm9l.mongodb.net:27017', 'ac-gv2ej15-shard-00-02.riuxm9l.mongodb.net:27017', 'ac-gv2ej15-shard-00-00.riuxm9l.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-w630az-shard-0', tls=True), 'test')

# %%
db=client["database"]

# %%
col=db["course"]

# %%
col1=db["student"]

# %%
data={
    'course': ['python','data scientist','java'],
    'instructor':['kuldeep','udhav','aaksh'],
    'date':'12-12-2025'
}

# %%
col.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 col.insert_one(data)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)
#     826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2876, in _ClientConnectionRetryable._write(self)
#    2874 is_mongos = False
#    2875 self._server = self._get_server()
# -> 2876 with self._client._checkout(self._server, self._session) as conn:
#    2877     max_wire_version = conn.max_wire_version
#    2878     sessions_supported = (
#    2879         self._session
#    2880         and self._server.description.retryable_writes_supported
#    2881         and conn.supports_sessions
#    2882     )
#
# File /opt/anaconda3/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1777, in MongoClient._checkout(self, server, session)
#    1775     yield session._pinned_connection
#    1776     return
# -> 1777 with server.checkout(handler=err_handler) as conn:
#    1778     # Pin this session to the selected server or connection.
#    1779     if (
#    1780         in_txn
#    1781         and session
#    (...)
#    1786         )
#    1787     ):
#    1788         session._pin(server, conn)
#
# File /opt/anaconda3/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/pool.py:1118, in Pool.checkout(self, handler)
#    1109 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1110     _debug_log(
#    1111         _CONNECTION_LOGGER,
#    1112         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)
#    1115         serverPort=self.address[1],
#    1116     )
# -> 1118 conn = self._get_conn(checkout_started_time, handler=handler)
#    1120 duration = time.monotonic() - checkout_started_time
#    1121 if self.enabled_for_cmap:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/pool.py:1280, in Pool._get_conn(self, checkout_started_time, handler)
#    1278 else:  # We need to create a new connection
#    1279     try:
# -> 1280         conn = self.connect(handler=handler)
#    1281     finally:
#    1282         with self._max_connecting_cond:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/pool.py:1072, in Pool.connect(self, handler)
#    1069     if handler:
#    1070         handler.contribute_socket(conn, completed_handshake=False)
# -> 1072     conn.authenticate()
#    1073 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1074 except BaseException:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/pool.py:525, in Connection.authenticate(self, reauthenticate)
#     522 if creds:
#     523     from pymongo.synchronous import auth
# --> 525     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     526 self.ready = True
#     527 duration = time.monotonic() - self.creation_time
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/auth.py:135, in _authenticate_scram(credentials, conn, mechanism)
#     128 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     130 cmd = {
#     131     "saslContinue": 1,
#     132     "conversationId": res["conversationId"],
#     133     "payload": Binary(client_final),
#     134 }
# --> 135 res = conn.command(source, cmd)
#     137 parsed = _parse_scram_response(res["payload"])
#     138 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/pymongo/helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}
