# %%
#Itratable
# someting which we can iterate or get into loop eg. string list tuple,set dictionary

# %%
li=[3.,5,"kuldepeb",8]
for i in li:
    print(i)
# Out:
# 3.0
# 5
# kuldepeb
# 8

# %%
for i in "kuldeep":
    print(i)
# Out:
# k
# u
# l
# d
# e
# e
# p

# %%
# if want to convert into iterator using iter function

# %%
iter(li)

# %%
k=iter(li)

# %%
next(k)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 next(k)
#
# StopIteration:

# %%
# genrator is another way of converting object into iterator

# %%
def fucn(n):
    for i in range(n):
        return i**2

# %%
fucn(3)
# Out:
# 0

# %%
# above cannot go in loop

# %%
def fucn(n):
    for i in range(n):
        yield i**2

# %%
type(fucn(3))
# Out:
# generator

# %%
k=fucn(3)

# %%
next(k)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 next(k)
#
# StopIteration:
